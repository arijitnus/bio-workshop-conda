# %% [markdown]
# # Bioinformatics Tools Demo
# This notebook demonstrates basic usage of tools installed via Bioconda.

# %%
# !fastqc --version
# !cutadapt --version
# !blastn -version
# !quast --version
# !prokka --version
# !unicycler --version
# !exec_annotation -h  # for kofamscan

# %% [markdown]
# ## Upload and Analyze a File
# You can upload a file via the Jupyter interface and run tools like this:

# %%
# Example: Run FastQC on uploaded FASTQ file
# !fastqc my_reads.fastq
